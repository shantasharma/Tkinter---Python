# %%
from tkinter import *
import tkinter.messagebox
import random
tk = Tk()
tk.title("X FAIL")
tk.minsize(80, 300)
tk.title("MS")

l = Label(tk, text = "MindSweeper").place(x = 0, y = 0)
bclick = True
flag = 0

def disableButton():
    button1.configure(state=DISABLED)
    button2.configure(state=DISABLED)
    button3.configure(state=DISABLED)
    button4.configure(state=DISABLED)
    button5.configure(state=DISABLED)
    button6.configure(state=DISABLED)
    button7.configure(state=DISABLED)
    button8.configure(state=DISABLED)
    button9.configure(state=DISABLED)
    button10.configure(state=DISABLED)
    button11.configure(state=DISABLED)
    button12.configure(state=DISABLED)
    button13.configure(state=DISABLED)
    button14.configure(state=DISABLED)
    button15.configure(state=DISABLED)
    button16.configure(state=DISABLED)
    button17.configure(state=DISABLED)
    button18.configure(state=DISABLED)



def btnClick(buttons):
    num = ['1', '2','X', '3', '4', '5', '6', 'X', 'X', 'X']
    global bclick, flag, player1_name, playerb, pa
    if buttons["text"] == " " and bclick == True:
        buttons["text"] = random.choice(num)
        bclick = False
        checkForWin()
        flag += 1

    
    elif buttons["text"] == " " and bclick == False:
        buttons["text"] = random.choice(num)
        bclick = True
        checkForWin()
        flag += 1
    
    else:
        tkinter.messagebox.showinfo("minsweeper", "Button already Clicked!")

def checkForWin():
    global flag
    if (button1['text']  == 'X' or button2['text'] == 'X'  or button3['text'] == 'X' or
        button4['text']  == 'X' or button5['text'] == 'X'  or button6['text'] == 'X' or
        button7['text']  == 'X' or button8['text'] == 'X'  or button9['text'] == 'X' or
        button10['text'] == 'X' or button11['text'] == 'X' or button12['text'] == 'X' or
        button13['text'] == 'X' or button14['text'] == 'X' or button15['text'] == 'X' or
        button16['text'] == 'X' or button17['text'] == 'X' or button18['text'] == 'X') :
        disableButton()
        if (flag < 0):
            tkinter.messagebox.showinfo("minsweeped", "You lost")
        else:
            tkinter.messagebox.showinfo("minsweeped", "Your score is {0}".format(flag - 1))
    else:
        flag += 1

buttons = StringVar()



button1 = Button(tk, text=" ", font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button1))
button1.grid(row=3, column=0)

button2 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button2))
button2.grid(row=3, column=1)

button3 = Button(tk, text=' ',font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button3))
button3.grid(row=3, column=2)

button4 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button4))
button4.grid(row=4, column=0)

button5 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button5))
button5.grid(row=4, column=1)

button6 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button6))
button6.grid(row=4, column=2)

button7 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button7))
button7.grid(row=5, column=0)

button8 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button8))
button8.grid(row=5, column=1)

button9 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button9))
button9.grid(row=5, column=2)
        
button10 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white',height=1, width=2, command=lambda: btnClick(button10))
button10.grid(row=6, column=0)

button11 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button11))
button11.grid(row=6, column=1)

button12 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button12))
button12.grid(row=6, column=2)

button13 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button13))
button13.grid(row=7, column=0)

button14 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button14))
button14.grid(row=7, column=1)

button15 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button15))
button15.grid(row=7, column=2)

button16 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button16))
button16.grid(row=8, column=0)

button17 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button17))
button17.grid(row=8, column=1)

button18 = Button(tk, text=' ', font='Times 20 bold', bg='light gray', fg='white', height=1, width=2, command=lambda: btnClick(button18))
button18.grid(row=8, column=2)


tk.mainloop()
